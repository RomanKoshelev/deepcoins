# %% [markdown]
# # Model-1

# %%
import tensorflow as tf
import numpy as np
from timeit import default_timer as timer
from dataset import Dataset
from layers import *
from networks import *
from model import Model
from dbase import DataBase
from visualisation import show_similarity

# %%
tr_data_path = "/netforge/datasets/private/roman/coins/2017-11-29/datasets/train/5557_300_128_128_1_uint8_aug2.npy"
va_data_path = "/netforge/datasets/private/roman/coins/2017-11-29/datasets/valid/550_300_128_128_1_uint8_aug2.npy"
model_path   = "models/001/"

# %% [markdown]
# ## Dataset

# %%
# %%time
tr_dataset   = Dataset(tr_data_path)
va_dataset   = Dataset(va_data_path)
tr_dataset.load()
va_dataset.load()
image_shape  = list(tr_dataset.data.shape[-3:])
print("Train:", list(tr_dataset.data.shape), tr_dataset.data.dtype)
print("Valid:", list(va_dataset.data.shape), va_dataset.data.dtype)
print('-'*50)
# Out:
# Train: [5557, 300, 128, 128, 1] uint8
# Valid: [550, 300, 128, 128, 1] uint8
# --------------------------------------------------
# CPU times: user 348 ms, sys: 1min 5s, total: 1min 5s
# Wall time: 2min 6s

# %% [markdown]
# ## Build

# %%
# %%time
out_dims       = 300
margin         = .2
acc_batch_size = 300
network        = simple_conv

model = Model(image_shape, out_dims, acc_batch_size)
model.build(network)
# Out:
# CPU times: user 4.82 s, sys: 784 ms, total: 5.61 s
# Wall time: 5.63 s

# %%
# %%time
accs = []
for i in range(1):
    acc = model.calc_acc(tr_dataset)
    accs.append(acc)
acc = np.mean(accs)
print("Acc: %.1f%%" % (acc*100))
# Out:
# Acc: 23.0%
# CPU times: user 1.4 s, sys: 1.1 s, total: 2.5 s
# Wall time: 2.46 s

# %% [markdown]
# ## Train

# %%
# %%time
model.train(
    step_num   = 100000, 
    batch_size = 64,
    lr         = {1:1e-4, 0.01:3e-5, 0.003:1e-5}, #7e-3:3e-6, 5e-3:1e-6, 3e-3:3e-7, 1.5e-3:1e-7}, 
    log_every  = 30,
    tr_dataset = tr_dataset,
    va_dataset = va_dataset,
    margin     = margin,
    log_scale  = False)

model.save(model_path)
print('-'*50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/prj/deepcoins/model.py in save(self, path)
#     178         with self._graph.as_default(), tf.variable_scope(self.scope):
#     179             saver = tf.train.Saver()
# --> 180         saver.save(self._session, path)
#     181
#     182     def restore(self, path):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1599       if context.in_graph_mode():
#    1600         with sess.graph.as_default():
# -> 1601           self.export_meta_graph(meta_graph_filename)
#    1602
#    1603     if self._is_empty:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in export_meta_graph(self, filename, collection_list, as_text, export_scope, clear_devices, clear_extraneous_savers)
#    1637         export_scope=export_scope,
#    1638         clear_devices=clear_devices,
# -> 1639         clear_extraneous_savers=clear_extraneous_savers)
#    1640
#    1641   def restore(self, sess, save_path):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in export_meta_graph(filename, meta_info_def, graph_def, saver_def, collection_list, as_text, graph, export_scope, clear_devices, clear_extraneous_savers, **kwargs)
#    1881       clear_devices=clear_devices,
#    1882       clear_extraneous_savers=clear_extraneous_savers,
# -> 1883       **kwargs)
#    1884   return meta_graph_def
#    1885
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/meta_graph.py in export_scoped_meta_graph(filename, graph_def, graph, export_scope, as_text, unbound_inputs_col_name, clear_devices, saver_def, clear_extraneous_savers, **kwargs)
#     841         os.path.dirname(filename),
#     842         os.path.basename(filename),
# --> 843         as_text=as_text)
#     844
#     845   return scoped_meta_graph_def, var_list
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/graph_io.py in write_graph(graph_or_graph_def, logdir, name, as_text)
#      69                                         text_format.MessageToString(graph_def))
#      70   else:
# ---> 71     file_io.atomic_write_string_to_file(path, graph_def.SerializeToString())
#      72   return path
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in SerializeToString(self)
#    1033           'Message %s is missing required fields: %s' % (
#    1034           self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1035     return self.SerializePartialToString()
#    1036   cls.SerializeToString = SerializeToString
#    1037
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in SerializePartialToString(self)
#    1042   def SerializePartialToString(self):
#    1043     out = BytesIO()
# -> 1044     self._InternalSerialize(out.write)
#    1045     return out.getvalue()
#    1046   cls.SerializePartialToString = SerializePartialToString
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in InternalSerialize(self, write_bytes)
#    1048   def InternalSerialize(self, write_bytes):
#    1049     for field_descriptor, field_value in self.ListFields():
# -> 1050       field_descriptor._encoder(write_bytes, field_value)
#    1051     for tag_bytes, value_bytes in self._unknown_fields:
#    1052       write_bytes(tag_bytes)
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in EncodeField(write, value)
#     761       write(tag)
#     762       local_EncodeVarint(write, value.ByteSize())
# --> 763       return value._InternalSerialize(write)
#     764     return EncodeField
#     765
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in InternalSerialize(self, write_bytes)
#    1048   def InternalSerialize(self, write_bytes):
#    1049     for field_descriptor, field_value in self.ListFields():
# -> 1050       field_descriptor._encoder(write_bytes, field_value)
#    1051     for tag_bytes, value_bytes in self._unknown_fields:
#    1052       write_bytes(tag_bytes)
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in EncodeRepeatedField(write, value)
#     755         write(tag)
#     756         local_EncodeVarint(write, element.ByteSize())
# --> 757         element._InternalSerialize(write)
#     758     return EncodeRepeatedField
#     759   else:
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in InternalSerialize(self, write_bytes)
#    1048   def InternalSerialize(self, write_bytes):
#    1049     for field_descriptor, field_value in self.ListFields():
# -> 1050       field_descriptor._encoder(write_bytes, field_value)
#    1051     for tag_bytes, value_bytes in self._unknown_fields:
#    1052       write_bytes(tag_bytes)
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in EncodeField(write, value)
#     819     for key in value:
#     820       entry_msg = message_type._concrete_class(key=key, value=value[key])
# --> 821       encode_message(write, entry_msg)
#     822
#     823   return EncodeField
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in EncodeField(write, value)
#     760     def EncodeField(write, value):
#     761       write(tag)
# --> 762       local_EncodeVarint(write, value.ByteSize())
#     763       return value._InternalSerialize(write)
#     764     return EncodeField
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1010     size = 0
#    1011     for field_descriptor, field_value in self.ListFields():
# -> 1012       size += field_descriptor._sizer(field_value)
#    1013
#    1014     for tag_bytes, value_bytes in self._unknown_fields:
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in FieldSize(value)
#     306   else:
#     307     def FieldSize(value):
# --> 308       l = value.ByteSize()
#     309       return tag_size + local_VarintSize(l) + l
#     310     return FieldSize
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1010     size = 0
#    1011     for field_descriptor, field_value in self.ListFields():
# -> 1012       size += field_descriptor._sizer(field_value)
#    1013
#    1014     for tag_bytes, value_bytes in self._unknown_fields:
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/encoder.py in FieldSize(value)
#     306   else:
#     307     def FieldSize(value):
# --> 308       l = value.ByteSize()
#     309       return tag_size + local_VarintSize(l) + l
#     310     return FieldSize
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1009
#    1010     size = 0
# -> 1011     for field_descriptor, field_value in self.ListFields():
#    1012       size += field_descriptor._sizer(field_value)
#    1013
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in ListFields(self)
#     774
#     775   def ListFields(self):
# --> 776     all_fields = [item for item in self._fields.items() if _IsPresent(item)]
#     777     all_fields.sort(key = lambda item: item[0].number)
#     778     return all_fields
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in <listcomp>(.0)
#     774
#     775   def ListFields(self):
# --> 776     all_fields = [item for item in self._fields.items() if _IsPresent(item)]
#     777     all_fields.sort(key = lambda item: item[0].number)
#     778     return all_fields
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/python_message.py in _IsPresent(item)
#     763
#     764   if item[0].label == _FieldDescriptor.LABEL_REPEATED:
# --> 765     return bool(item[1])
#     766   elif item[0].cpp_type == _FieldDescriptor.CPPTYPE_MESSAGE:
#     767     return item[1]._is_present_in_parent
#
# ~/.local/lib/python3.5/site-packages/google/protobuf/internal/containers.py in __len__(self)
#     204     return self._values[key]
#     205
# --> 206   def __len__(self):
#     207     """Returns the number of elements in the container."""
#     208     return len(self._values)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Database

# %%
# %%time
ethalons  = tr_dataset.get_ethalons()  # tr_dataset va_dataset
augmented = tr_dataset.get_augmented() # get_augmented() get_ethalons()

dbase     = DataBase()
dbase.build(model, ethalons)
print("Ethalons :", list(ethalons.shape),  ethalons.dtype)
print("Augmented:", list(augmented.shape), augmented.dtype)
print('-'*50)
# Out:
# Ethalons : [5557, 128, 128, 1] float32
# Augmented: [5557, 128, 128, 1] float32
# --------------------------------------------------
# CPU times: user 1.51 s, sys: 2.49 s, total: 4 s
# Wall time: 3.82 s

# %% [markdown]
# ## Accuracy

# %%
# %%time
def accuracy(ind, k):
    assert 0 < k <= ind.shape[1]
    err = 0
    N   = len(ind)
    for i in range(N):
        ok = False
        for j in range(k):
            if i==ind[i,j]:
                ok = True
        err+= not ok
    return ((N-err)/N*100)

start = timer()
ind, dist = dbase.query(augmented, 3)
t = timer() - start
n = augmented.shape[0]

print("Database   : %s" % list(dbase.embeds.shape))
print("Request    : %s" % list(augmented.shape))
print("Performance: %.0f img/sec" % (n/t))
print('-'*50)
for k in range(1, ind.shape[1]+1):
    print("Accuracy@%d: %.1f%%" % (k, accuracy(ind, k)))
print('-'*50)
# Out:
# Database   : [5557, 300]
# Request    : [5557, 128, 128, 1]
# Performance: 310 img/sec
# --------------------------------------------------
# Accuracy@1: 81.7%
# Accuracy@2: 87.7%
# Accuracy@3: 90.3%
# --------------------------------------------------
# CPU times: user 18.3 s, sys: 4 ms, total: 18.3 s
# Wall time: 17.9 s

# %% [markdown]
# ## Search

# %%
def search(request, max_k=0):
    num = 20
    per = np.random.choice(range(len(request)), num, replace=False)
    request  = request[per]
    ethalons = dbase.images
    ind, dist  = dbase.query(request, 3)
    for k in range(0, max_k+1):
        print("Average distance: %.2f" % np.mean(dist[:,k]))
        im2 = ethalons[ind[:,k]]
        sim = 1-dist[:,k]
        show_similarity(request, im2, sim, cols=4)

search(augmented)
# Out:
# Average distance: 0.45

# %% [markdown]
# ## Restore

# %%
# %time
model.restore(model_path)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 12.6 µs
# INFO:tensorflow:Restoring parameters from models/009/
