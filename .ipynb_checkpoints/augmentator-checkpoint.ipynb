# %% [markdown]
# # Augmentator

# %%
# %matplotlib inline
import numpy as np
import image_tools as imt
from augmentator import Augmentator
from timeit import default_timer as timer

# %%
# %%time
image_shape = [128,128,3]
image_path  = "/netforge/datasets/private/roman/coins/2017-11-29/images/valid"
aug         = Augmentator()
ethalons    = imt.load(image_path)
ethalons    = imt.resize(ethalons, image_shape)
print(ethalons.dtype, ethalons.shape)
# Out:
# uint8 (550, 128, 128, 3)
# CPU times: user 380 ms, sys: 152 ms, total: 532 ms
# Wall time: 537 ms

# %% [markdown]
# ## Test performance

# %%
# %%time
start = timer()
images = aug.augment(ethalons)
images = imt.grayscale(images)
t = timer() - start

print("Performance: %.1f ips" % (len(images)/t))
print('-'*50)
print(images.dtype, images.shape)
# Out:
# Performance: 152.6 ips
# --------------------------------------------------
# float16 (550, 128, 128, 1)
# CPU times: user 3.86 s, sys: 1.96 s, total: 5.82 s
# Wall time: 3.61 s

# %% [markdown]
# ## Test quality

# %%
# %%time
aug    = Augmentator()
images = imt.choice(ethalons, 42)
images = aug.augment(images)
images = imt.grayscale(images)
imt.plot(images, 6)
# Out:
# CPU times: user 3.12 s, sys: 340 ms, total: 3.46 s
# Wall time: 3.09 s
