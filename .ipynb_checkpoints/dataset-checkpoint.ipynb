# %% [markdown]
# # Dataset

# %%
import numpy as np
from dataset import Dataset
import image_tools as imt
# %matplotlib inline

# %% [markdown]
# ## Load

# %%
# %%time
path = "/netforge/datasets/private/roman/coins/2017-11-29/datasets/100_300_128_128_1_uint8.npy"
dataset = Dataset(path)
dataset.load()
data = dataset.data

print("Data:", data.dtype, data.shape, data.nbytes/1024/1024, "MB")
print("-"*50)
# Out:
# Data: uint8 (20, 30, 128, 128, 1) 9.375 MB
# --------------------------------------------------
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 3.75 ms

# %% [markdown]
# ## Show

# %%
images = data[7,:12]
images = imt.uint8_to_float32(images)
imt.plot(images, 6)

# %% [markdown]
# ## Batching

# %%
bs = 12
im1, im2, im3 = dataset.get_next_batch(bs)

batch = np.concatenate((im1,im2,im3))
print(batch.shape)
imt.plot(batch, bs)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-0d33e1e8c228> in <module>()
#       1 bs = 12
# ----> 2 im1, im2, im3 = dataset.get_next_batch(bs)
#       3
#       4 batch = np.concatenate((im1,im2,im3))
#       5 print(batch.shape)
#
# ~/prj/deepcoins/dataset.py in get_next_batch(self, bs)
#      13     def get_next_batch(self, bs):
#      14         n,a = self.data.shape[:2]
# ---> 15         assert 2*bs<=n and bs<=a
#      16         idx_n   = np.random.choice(np.arange(n), bs*2, replace=False)
#      17         idx_a_1 = np.random.choice(np.arange(a), bs,   replace=False)
#
# AssertionError:
