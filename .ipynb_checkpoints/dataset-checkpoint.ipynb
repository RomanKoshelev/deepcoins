# %% [markdown]
# # Dataset

# %%
import numpy as np
from dataset import Dataset
import image_tools as imt
# %matplotlib inline

# %% [markdown]
# ## Load

# %%
# %%time
path = "/netforge/datasets/private/roman/coins/2017-11-29/datasets/train/500_300_128_128_1_uint8.npy"
dataset = Dataset(path)
dataset.load()
data = dataset.data

print("Data:", data.dtype, data.shape, data.nbytes/1024/1024, "MB")
print("-"*50)
# Out:
# Data: uint8 (500, 300, 128, 128, 1) 2343.75 MB
# --------------------------------------------------
# CPU times: user 0 ns, sys: 588 ms, total: 588 ms
# Wall time: 584 ms

# %% [markdown]
# ## Show

# %%
images = data[7,:24]
images = imt.uint8_to_float32(images)
imt.plot(images, 6)

# %% [markdown]
# ## Batching

# %%
bs = 12
im1, im2, im3 = dataset.get_next_batch(bs)

batch = np.concatenate((im1,im2,im3))
print(batch.shape, batch.dtype)
imt.plot(batch, bs)
# Out:
# (36, 128, 128, 1) float32

# %% [markdown]
# # Ethalons

# %%
images = imt.uint8_to_float32(dataset.get_ethalons()[:12])
imt.plot(images, 6)

# %% [markdown]
# # Augmented

# %%
images = imt.uint8_to_float32(dataset.get_augmented()[:12])
imt.plot(images, 6)
