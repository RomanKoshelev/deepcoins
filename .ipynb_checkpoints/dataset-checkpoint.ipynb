# %% [markdown]
# # Dataset

# %%
import numpy as np
from dataset import Dataset
import image_tools as imt
# %matplotlib inline

# %% [markdown]
# ## Load

# %%
# %%time
path = "/netforge/datasets/private/roman/coins/2017-11-29/datasets/train/100_300_128_128_1_uint8.npy"
dataset = Dataset(path)
dataset.load()
data = dataset.data

print("Data:", data.dtype, data.shape, data.nbytes/1024/1024, "MB")
print("-"*50)
# Out:
# Data: uint8 (100, 300, 128, 128, 1) 468.75 MB
# --------------------------------------------------
# CPU times: user 8 ms, sys: 144 ms, total: 152 ms
# Wall time: 151 ms

# %% [markdown]
# ## Show

# %%
images = data[7,:24]
images = imt.uint8_to_float32(images)
imt.plot(images, 6)

# %% [markdown]
# ## Batching

# %%
bs = 200
n  = 12

im1, im2, im3 = dataset.get_next_batch(bs)

batch = np.concatenate((im1[:n],im2[:n],im3[:n]))
print(batch.shape, batch.dtype)
imt.plot(batch, n)
# Out:
# (36, 128, 128, 1) float32

# %% [markdown]
# # Ethalons

# %%
images = imt.uint8_to_float32(dataset.get_ethalons()[:24])
imt.plot(images, 8)

# %% [markdown]
# # Augmented

# %%
images = imt.uint8_to_float32(dataset.get_augmented()[:24])
imt.plot(images, 8)
